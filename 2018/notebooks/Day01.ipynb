-- %%
file <- lines <$> readFile "../input/input01.txt"

-- %%
readI ('-':xs) = (negate 1) * (read xs :: Int)
readI ('+':xs) = (read xs :: Int)

sum $ map readI file
-- Out:
-- Line 1: Redundant bracket
-- Found:
-- (negate 1) * (read xs :: Int)
-- Why not:
-- negate 1 * (read xs :: Int)Line 2: Redundant bracket
-- Found:
-- (read xs :: Int)
-- Why not:
-- read xs :: Int
-- 533

-- %%
frequencies = scanl (+) 0 (cycle (map readI file))

-- %%
import qualified Data.Set as Set
import Data.List (foldl')

foldl' (\s i -> if Set.member i s then (error (show i)) else Set.insert i s) Set.empty frequencies
-- Out:
-- Line 1: Redundant bracket
-- Found:
-- if Set.member i s then (error (show i)) else Set.insert i s
-- Why not:
-- if Set.member i s then error (show i) else Set.insert i s
-- 73272
-- CallStack (from HasCallStack):
--   error, called at <interactive>:1:41 in interactive:Ghci71
