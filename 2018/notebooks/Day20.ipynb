-- %%
import AdventOfCode

-- %%
input <- dayString 20

-- %%
data Path a = Path [Segment a]
    deriving (Eq, Show)

data Segment a
    = Leaf a
    | Node [Path a]
    deriving (Eq, Show)

-- %%
{-# LANGUAGE ScopedTypeVariables #-}
import Data.List

parseLeaf str = let
    (t, rest) = span (`elem` "NEWS") str
    in (Leaf t, rest)

parseNode acc ('(':str) = let
    (t, rest) = parsePath [] str
    in parseNode (acc++[t]) rest
parseNode acc ('|':str) = let
    (t, rest) = parsePath [] str
    in parseNode (acc++[t]) rest
parseNode acc (')':str) = (Node acc, str)

parsePath :: [Segment String] -> String -> (Path String, String)
parsePath acc []  = (Path acc, [])
parsePath acc str@(x:xs) = case x of
    '(' -> let
        (group, str') = parseNode [] str
        in parsePath (acc++[group]) str'
    '|' -> (Path acc, str)
    ')' -> (Path acc, str)
    _ -> let
        (chunk, str') = parseLeaf str
        in parsePath (acc++[chunk]) str'

parsePath [] "NSW(EE|NN|)S"
-- Out:
-- (Path [Leaf "NSW",Node [Path [Leaf "EE"],Path [Leaf "NN"],Path []],Leaf "S"],"")

-- %%
trimmed = init $ tail input
processed = fst $ parsePath [] trimmed

-- %%
maxPath (Path ts) = sum $ map maxSegment ts
maxSegment (Leaf str) = length str
maxSegment (Node rs) = let
    subpaths = map maxPath rs
    in if 0 `elem` subpaths then 0 else maximum subpaths

maxPath processed
-- Out:
-- 3958

-- %%
processed
-- Out:
-- Path [Leaf "WSSSEESESWSWSSWNNNENWWWWNNWWNWSSWNNNEEENEESE",Node [Path [Leaf "NENEENEESENENEEESWWSWSEENEESENNWNENENNEESSW",Node [Path [Leaf "SWSESSW",Node [Path [Leaf "N"],Path [Leaf "SESSWSSEEENNEESSENESEENNW",Node [Path [Leaf "NNWWS",Node [Path [Leaf "ESWENW"],Path []],Leaf "WWNNNENWWN",Node [Path [Leaf "EEENEEEENENWNENESEESSESWWSESENENENWNWNNESENNNNEEEENNNWNNESESSESSSW",Node [Path [Leaf "WWWWSEESWWSS",Node [Path [Leaf "W"],Path [Leaf "SSSEESEEEEESESWWSEESESWWWWWNE",Node [Path [Leaf "EE"],Path [Leaf "NWWWSWNWWSSWSESENESSSSENNESSSWWSESSEENWNEEEESESSSSEENESSWSEESWSESESENEESWSWWSWNNWWSSSWNWWWWSWNWNWSSESWWSESWSWSEEEN",Node [Path [Leaf "W"],Path [Leaf "EESWSSSWWNN",Node [Path [Leaf "ESNW"],Path []],Leaf "WSSWNNWNWNENNNE",Node [Path [Leaf "SS"],Path [Leaf "NNNE",Node [Path [Leaf "NNNNEESSES",Node [Path [Leaf "WWNNSSEE"],Path []],Leaf "SEENENEE",Node [Path [Leaf "E",Node [Path [Leaf "E"],Path [Leaf "NWN",Node [Path [Leaf "WNWSS",Node [Path [Leaf "WW",Node [Path [Leaf "S",Node [Path [Leaf "S"],Path [Leaf "E"]]],Path [Leaf "NW",Node [Path [Leaf "NENWNNN",Node [Path [Leaf "WSSSWWS",Node [Path [Leaf "WWWNNWNWNNEES",Node [Path [Leaf "W"],Path [Leaf "ES",Node [Path [Leaf "SE",Node [Path [Leaf "SWEN"],Path []],Leaf "ENN",Node [Path [Leaf "ESSNNW"],Path []],Leaf "W",Node [Path [Leaf "NENWW",Node [Path [Leaf "NENNNWN",Node [Path [Leaf "E"],Path [Leaf "WNWNWSWNNNWNWSW",Node [Path [Leaf "SESSSSESSWSWNN",Node [Path [Leaf "WWNN",Node [Path [Leaf "ESENNN"],Path [Leaf "WWWSWSEESSWNWSWSSEEN",Node [Path [Leaf "EEENE",Node [Path [Leaf "SEESSSEE",Node [Path [Leaf "SSWNWSSEESWWWWNNNE",Node [Path [Leaf "SS"],Path [Leaf "NWNN",Node [Path [Leaf "ESNW"],Path []],Leaf "WSWW",Node [Path [Leaf "NEWS"],Path []],Leaf "SEESWSSE",Node [Path [Leaf "SWSWSSSSWSWNWWSSSSWNNWNNWNNENWNWNWSWNNENWNWNEEEEEESSSSS",Node [Path [Leaf "WNWNENWN",Node [Path [Leaf "W",Node [Path [Leaf "W"],Path [Leaf "SS"]]],Path [Leaf "E"]]],Path [Leaf "SESWS",Node [Path [Leaf "W"],Path [Leaf "SS"],Path [Leaf "EENEE",Node [Path [Leaf "SWEN"],Path []],Leaf "NNWSWNNNW",Node [Path [Leaf "NNNN",Node [Path [Leaf "WNNNWNNNEN",Node [Path [Leaf "EE",Node [Path [Leaf "ENNSSW"],Path []],Leaf "SWSWSE",Node [Path [Leaf "ENSW"],Path []],Leaf "SSS"],Path [Leaf "WWNNWNEN",Node [Path [Leaf "WWN",Node [Path [Leaf "WWSSE",Node [Path [Leaf "N"],Path [Leaf "ESWSEESWWSSWWWSWSWNN",Node [Path [Leaf "WSSSWNWWNWNNE",Node [Path [Leaf "NWWWNNWSWWWNNNWWWSEESWSWSSWSWSWWSSWNWNWWSSSWWSSWSWNWNWWWWSWWSESEEN",Node [Path [Leaf "W"],Path [Leaf "EE",Node [Path [Leaf "NWWEES"],Path []],Leaf "SE",Node [Path [Leaf "N"],Path [Leaf "SEEN",Node [Path [Leaf "EEN",Node [Path [Leaf "NEN",Node [Path [Leaf "EESWSESEEEEENNWSWNWNEEEEESWSSEEESENNENNNWSWW",Node [Path [Leaf "NNNWNN",Node [Path [Leaf "WSWSWSS",Node [Path [Leaf "W",Node [Path [Leaf "WW",Node [Path [Leaf "SSSEWNNN"],Path []],Leaf "WNW",Node [Path [Leaf "N"],Path [Leaf "S"]]],Path [Leaf "NN"]]],Path [Leaf "ENE",Node [Path [Leaf "ESWENW"],Path []],Leaf "N"]]],Path [Leaf "NESSEEENEEN",Node [Path [Leaf "WNWSWW",Node [Path [Leaf "SEWN"],Path []],Leaf "N",Node [Path [Leaf "E"],Path [Leaf "W",Node [Path [Leaf "W"],Path [Leaf "N"]]]]],Path [Leaf "ESSSWW",Node [Path [Leaf "NEWS"],Path []],Leaf "WS",Node [Path [Leaf "ESESWSSSSSW",Node [Path [Leaf "NN"],Path [Leaf "WSEESSWSWSWNWSSWNWWNNESENENE",Node [Path [Leaf "NNWNWSWNWWSWSSSSWNWWWSWNWSSEESSSWSWNWSSEEEEENENWNNEN",Node [Path [Leaf "EE",Node [Path [Leaf "SWS",Node [Path [Leaf "SENEE",Node [Path [Leaf "NWES"],Path []],Leaf "SENEESSENNN",Node [Path [Leaf "EEN",Node [Path [Leaf "NEESENEEENENESESEENNE",Node [Path [Leaf "NNWWNWSWWWWNWNENNWWNENN",Node [Path [Leaf "ESEEESWW",Node [Path [Leaf "W"],Path [Leaf "SEESWSE",Node [Path [Leaf "SWWNNSSEEN"],Path []],Leaf "ENESE",Node [Path [Leaf "SENSWN"],Path []],Leaf "NNWNW",Node [Path [Leaf "NEN",Node [Path [Leaf "NESSSEEENWNENN",Node [Path [Leaf "WSW",Node [Path [Leaf "NWES"],Path []],Leaf "SS"],Path [Leaf "NNESSE",Node [Path [Leaf "SWSSSENNESS",Node [Path [Leaf "NNWSSWENNESS"],Path []]],Path [Leaf "NN"]]]]] ...

-- %%
{-# LANGUAGE BangPatterns #-}

import qualified Data.Map.Strict as Map

move :: (Int, Int) -> Char -> (Int, Int)
move (x,y) c = case c of
    'N' -> (x, y+1)
    'W' -> (x-1, y)
    'E' -> (x+1, y)
    'S' -> (x, y-1)
    
visitString
    :: (Map.Map (Int, Int) Int)
    -> (Int, Int)
    -> Int
    -> String
    -> (Map.Map (Int, Int) Int, (Int, Int), Int)
visitString rooms curPos doorCount str = case str of
    [] -> (rooms, curPos, doorCount)
    _ -> update rooms curPos doorCount str
    where
        update rs pos count s = case s of
            [] -> (rs, pos, count)
            x:xs -> let
                pos' = move pos x
                count' = count + 1
                !rs' = Map.insertWith min pos' count' rs
                in update rs' pos' count' xs

-- %%
import Debug.Trace

visitTerms :: Map.Map (Int, Int) Int -> (Int, Int) -> Int -> [Segment String] -> [(Map.Map (Int, Int) Int, (Int, Int), Int)]
visitTerms !rooms curPos doorCount [] = [(rooms, curPos, doorCount)]
visitTerms !rooms curPos doorCount (Leaf str:ts) = traceShow (Map.size rooms) $ let
    (rooms', curPos', doorCount') = visitString rooms curPos doorCount str
    in visitTerms rooms' curPos' doorCount' ts
visitTerms !rooms curPos doorCount (Node rs:ts) = traceShow (Map.size rooms) $ do
        Path r <- rs
        visitTerms rooms curPos doorCount (r++ts)

-- %%
visitGraph (Path ts) =
    Map.unionsWith min $ map (\(rs,_,_) -> rs) $ visitTerms Map.empty (0,0) 0 ts

-- %%
visitGraph' (Path ts) = visitTerms Map.empty (0,0) 0 ts

visitGraph' processed

-- %%
Path ps = processed
length ps
head ps
Node bs = head $ tail ps
head bs
-- Out:
-- 2
-- Leaf "WSSSEESESWSWSSWNNNENWWWWNNWWNWSSWNNNEEENEESE"
-- Path [Leaf "NENEENEESENENEEESWWSWSEENEESENNWNENENNEESSW",Node [Path [Leaf "SWSESSW",Node [Path [Leaf "N"],Path [Leaf "SESSWSSEEENNEESSENESEENNW",Node [Path [Leaf "NNWWS",Node [Path [Leaf "ESWENW"],Path []],Leaf "WWNNNENWWN",Node [Path [Leaf "EEENEEEENENWNENESEESSESWWSESENENENWNWNNESENNNNEEEENNNWNNESESSESSSW",Node [Path [Leaf "WWWWSEESWWSS",Node [Path [Leaf "W"],Path [Leaf "SSSEESEEEEESESWWSEESESWWWWWNE",Node [Path [Leaf "EE"],Path [Leaf "NWWWSWNWWSSWSESENESSSSENNESSSWWSESSEENWNEEEESESSSSEENESSWSEESWSESESENEESWSWWSWNNWWSSSWNWWWWSWNWNWSSESWWSESWSWSEEEN",Node [Path [Leaf "W"],Path [Leaf "EESWSSSWWNN",Node [Path [Leaf "ESNW"],Path []],Leaf "WSSWNNWNWNENNNE",Node [Path [Leaf "SS"],Path [Leaf "NNNE",Node [Path [Leaf "NNNNEESSES",Node [Path [Leaf "WWNNSSEE"],Path []],Leaf "SEENENEE",Node [Path [Leaf "E",Node [Path [Leaf "E"],Path [Leaf "NWN",Node [Path [Leaf "WNWSS",Node [Path [Leaf "WW",Node [Path [Leaf "S",Node [Path [Leaf "S"],Path [Leaf "E"]]],Path [Leaf "NW",Node [Path [Leaf "NENWNNN",Node [Path [Leaf "WSSSWWS",Node [Path [Leaf "WWWNNWNWNNEES",Node [Path [Leaf "W"],Path [Leaf "ES",Node [Path [Leaf "SE",Node [Path [Leaf "SWEN"],Path []],Leaf "ENN",Node [Path [Leaf "ESSNNW"],Path []],Leaf "W",Node [Path [Leaf "NENWW",Node [Path [Leaf "NENNNWN",Node [Path [Leaf "E"],Path [Leaf "WNWNWSWNNNWNWSW",Node [Path [Leaf "SESSSSESSWSWNN",Node [Path [Leaf "WWNN",Node [Path [Leaf "ESENNN"],Path [Leaf "WWWSWSEESSWNWSWSSEEN",Node [Path [Leaf "EEENE",Node [Path [Leaf "SEESSSEE",Node [Path [Leaf "SSWNWSSEESWWWWNNNE",Node [Path [Leaf "SS"],Path [Leaf "NWNN",Node [Path [Leaf "ESNW"],Path []],Leaf "WSWW",Node [Path [Leaf "NEWS"],Path []],Leaf "SEESWSSE",Node [Path [Leaf "SWSWSSSSWSWNWWSSSSWNNWNNWNNENWNWNWSWNNENWNWNEEEEEESSSSS",Node [Path [Leaf "WNWNENWN",Node [Path [Leaf "W",Node [Path [Leaf "W"],Path [Leaf "SS"]]],Path [Leaf "E"]]],Path [Leaf "SESWS",Node [Path [Leaf "W"],Path [Leaf "SS"],Path [Leaf "EENEE",Node [Path [Leaf "SWEN"],Path []],Leaf "NNWSWNNNW",Node [Path [Leaf "NNNN",Node [Path [Leaf "WNNNWNNNEN",Node [Path [Leaf "EE",Node [Path [Leaf "ENNSSW"],Path []],Leaf "SWSWSE",Node [Path [Leaf "ENSW"],Path []],Leaf "SSS"],Path [Leaf "WWNNWNEN",Node [Path [Leaf "WWN",Node [Path [Leaf "WWSSE",Node [Path [Leaf "N"],Path [Leaf "ESWSEESWWSSWWWSWSWNN",Node [Path [Leaf "WSSSWNWWNWNNE",Node [Path [Leaf "NWWWNNWSWWWNNNWWWSEESWSWSSWSWSWWSSWNWNWWSSSWWSSWSWNWNWWWWSWWSESEEN",Node [Path [Leaf "W"],Path [Leaf "EE",Node [Path [Leaf "NWWEES"],Path []],Leaf "SE",Node [Path [Leaf "N"],Path [Leaf "SEEN",Node [Path [Leaf "EEN",Node [Path [Leaf "NEN",Node [Path [Leaf "EESWSESEEEEENNWSWNWNEEEEESWSSEEESENNENNNWSWW",Node [Path [Leaf "NNNWNN",Node [Path [Leaf "WSWSWSS",Node [Path [Leaf "W",Node [Path [Leaf "WW",Node [Path [Leaf "SSSEWNNN"],Path []],Leaf "WNW",Node [Path [Leaf "N"],Path [Leaf "S"]]],Path [Leaf "NN"]]],Path [Leaf "ENE",Node [Path [Leaf "ESWENW"],Path []],Leaf "N"]]],Path [Leaf "NESSEEENEEN",Node [Path [Leaf "WNWSWW",Node [Path [Leaf "SEWN"],Path []],Leaf "N",Node [Path [Leaf "E"],Path [Leaf "W",Node [Path [Leaf "W"],Path [Leaf "N"]]]]],Path [Leaf "ESSSWW",Node [Path [Leaf "NEWS"],Path []],Leaf "WS",Node [Path [Leaf "ESESWSSSSSW",Node [Path [Leaf "NN"],Path [Leaf "WSEESSWSWSWNWSSWNWWNNESENENE",Node [Path [Leaf "NNWNWSWNWWSWSSSSWNWWWSWNWSSEESSSWSWNWSSEEEEENENWNNEN",Node [Path [Leaf "EE",Node [Path [Leaf "SWS",Node [Path [Leaf "SENEE",Node [Path [Leaf "NWES"],Path []],Leaf "SENEESSENNN",Node [Path [Leaf "EEN",Node [Path [Leaf "NEESENEEENENESESEENNE",Node [Path [Leaf "NNWWNWSWWWWNWNENNWWNENN",Node [Path [Leaf "ESEEESWW",Node [Path [Leaf "W"],Path [Leaf "SEESWSE",Node [Path [Leaf "SWWNNSSEEN"],Path []],Leaf "ENESE",Node [Path [Leaf "SENSWN"],Path []],Leaf "NNWNW",Node [Path [Leaf "NEN",Node [Path [Leaf "NESSSEEENWNENN",Node [Path [Leaf "WSW",Node [Path [Leaf "NWES"],Path []],Leaf "SS"],Path [Leaf "NNESSE",Node [Path [Leaf "SWSSSENNESS",Node [Path [Leaf "NNWSSWENNESS"],Path []]],Path [Leaf "NN"]]]]],Path [Leaf "WW"]]],Path [Leaf "S"]]]]],Path [Leaf "W",Node [Pat ...
